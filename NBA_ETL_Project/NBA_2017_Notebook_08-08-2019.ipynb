# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pprint as pprint

from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder


# Output File (CSV)
nba_file = pd.read_csv('2017_nba_season_stats.csv')
nba_file.head()
# Out:
#    Year        Player Pos  Age   Tm   G  GS  PTS  Minutes Played   PER  ...    \
# 0  2017  Alex Abrines  SG   23  OKC  68   6  406            1055  10.1  ...
# 1  2017    Quincy Acy  PF   26  TOT  38   1  222             558  11.8  ...
# 2  2017    Quincy Acy  PF   26  DAL   6   0   13              48  -1.4  ...
# 3  2017    Quincy Acy  PF   26  BRK  32   1  209             510  13.1  ...
# 4  2017  Steven Adams   C   23  OKC  80  80  905            2389  16.5  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS.1
# 0  0.898   18   68   86   40   37    8   33  114    406
# 1  0.750   20   95  115   18   14   15   21   67    222
# 2  0.667    2    6    8    0    0    0    2    9     13
# 3  0.754   18   89  107   18   14   15   19   58    209
# 4  0.611  282  333  615   86   88   78  146  195    905
#
# [5 rows x 49 columns]

# %%
nba_teams = teams.get_teams()

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable='')
games = gamefinder.get_data_frames()
games
# Out:
# [      SEASON_ID     TEAM_ID TEAM_ABBREVIATION                 TEAM_NAME  \
#  0         22019  1611661325               IND             Indiana Fever
#  1         22019  1611661322               WAS        Washington Mystics
#  2         22019  1621980004               NWG           Girls Northwest
#  3         22019  1621980033               CNB                Boys China
#  4         22019  1621980028               MXB               Boys Mexico
#  5         22019  1621980023               MWB              Boys Midwest
#  6         22019  1621980007               MWG             Girls Midwest
#  7         22019  1621980017               CNG               Girls China
#  8         22019  1621980030               AMB               Boys Africa
#  9         22019  1621980008               SEG           Girls Southeast
#  10        22019  1621980024               SEB            Boys Southeast
#  11        22019  1611661329               CHI               Chicago Sky
# ...

# %%
## 76ers 2017 DataFrame

# %%
nba_teams = teams.get_teams()
# Select the dictionary for the 76ers, which contains their team ID
sixers = [team for team in nba_teams if team['abbreviation'] == 'PHI'][0]
sixers_id = sixers['id']

# %%
# Query for games where the sixers were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=sixers_id)
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
#Eliminate preseason
reg_season = games[games.GAME_DATE > '2017-10-16']
#Eliminate playoffs 
reg_season_final = reg_season[games.GAME_DATE < '2018-04-12']
reg_season_final
# Out:
# C:\Users\antho\Anaconda4\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 119     22017  1610612755               PHI  Philadelphia 76ers  0021701223
# 120     22017  1610612755               PHI  Philadelphia 76ers  0021701214
# 121     22017  1610612755               PHI  Philadelphia 76ers  0021701198
# 122     22017  1610612755               PHI  Philadelphia 76ers  0021701183
# 123     22017  1610612755               PHI  Philadelphia 76ers  0021701169
# 124     22017  1610612755               PHI  Philadelphia 76ers  0021701157
# 125     22017  1610612755               PHI  Philadelphia 76ers  0021701143
# 126     22017  1610612755               PHI  Philadelphia 76ers  0021701130
# 127     22017  1610612755               PHI  Philadelphia 76ers  0021701118
# ...

# %%
reg_season_final.sum(axis=0)
# Out:
# SEASON_ID            2201722017220172201722017220172201722017220172...
# TEAM_ID                                                   132070245910
# TEAM_ABBREVIATION    PHIPHIPHIPHIPHIPHIPHIPHIPHIPHIPHIPHIPHIPHIPHIP...
# TEAM_NAME            Philadelphia 76ersPhiladelphia 76ersPhiladelph...
# GAME_ID              0021701223002170121400217011980021701183002170...
# GAME_DATE            2018-04-112018-04-102018-04-082018-04-062018-0...
# MATCHUP              PHI vs. MILPHI @ ATLPHI vs. DALPHI vs. CLEPHI ...
# WL                   WWWWWWWWWWWWWWWWLWLWLWWLLWWWWWWWLWLLLWWLWWWLWW...
# MIN                                                              19787
# PTS                                                               9004
# FGM                                                               3349
# FGA                                                               7098
# FG_PCT                                                          38.742
# ...
